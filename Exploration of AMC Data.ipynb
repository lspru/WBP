# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_excel('All Runs.xlsx', sheet_name = 'First 27')

# %%
df
# Out:
#       Run  Trial          Time Stamp         Sensor      Value  SV1  SV2  SV3  \
# 0       1      1 2022-01-10 13:42:55  Occupancy 15s  50.943398  1.0  1.0  1.0
# 1       1      1 2022-01-10 13:43:00  Occupancy 15s  50.943398  1.0  1.0  1.0
# 2       1      1 2022-01-10 13:43:05  Occupancy 15s  50.943398  1.0  1.0  1.0
# 3       1      1 2022-01-10 13:51:40  Occupancy 15s  50.943398  1.0  1.0  1.0
# 4       1      1 2022-01-10 13:51:50  Occupancy 15s  50.943398  1.0  1.0  1.0
# ...   ...    ...                 ...            ...        ...  ...  ...  ...
# 8122   27      3 2022-02-03 11:16:40  Occupancy 15s  67.924530  2.0  2.0  1.5
# 8123   27      3 2022-02-03 11:16:45  Occupancy 15s  67.924530  2.0  2.0  1.5
# 8124   27      3 2022-02-03 11:16:50  Occupancy 15s  67.924530  2.0  2.0  1.5
# 8125   27      3 2022-02-03 11:23:10  Occupancy 15s  67.924530  2.0  2.0  1.5
# 8126   27      3 2022-02-03 11:23:15  Occupancy 15s  67.924530  2.0  2.0  1.5
#
# ...

# %%
X = df[['SV1', 'SV2', 'SV3', 'SV4', 'SV5', 'SV6', 'SV7', 'SV8', 'SV9', 'SV10']]
y = df[['Value']]

# %%
regr = linear_model.LinearRegression()
regr.fit(X.values, y.values)
# Out:
# LinearRegression()

# %%
predicted_effic = regr.predict([[1.0, 1.5, 2.0, 1.0, 1.5, 2.0, 1.0, 1.5, 2.0, 1.0]])
print(predicted_effic)
# Out:
# [[60.16681438]]

# %%
print(regr.coef_)
# Out:
# [[ 0.76727493  0.29770404 -0.43946325 -0.1144435   0.18719812  0.06700681
#    0.6167853   0.41065884  0.05455163  0.18116399]]
